# %%
import pandas as pd
import os
import nltk
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/gpt-4.csv'
print(os.path.exists(file_path))
# Out:
# True

# %%
df = pd.read_csv(file_path, on_bad_lines='skip', nrows=3000)
df
# Out:
#                                                    data  \
# 0     This 60-year-old male was hospitalized due to ...
# 1     A 39-year-old man was hospitalized due to an i...
# 2     One week after a positive COVID-19 result this...
# 3     This 69-year-old male was admitted to the ICU ...
# 4     This 57-year-old male was admitted to the ICU ...
# ...                                                 ...
# 2995  A 43-year-old female with dyspnoea was transfe...
# 2996  A 63-year-old female presented in 2016 with pa...
# 2997  A 72 year old female, with no significant past...
# 2998  A 32-year-old female at pregnancy week 22 was ...
# 2999  We report a case of a 40-year-old female (grav...
#
#                                            conversation
# 0     Doctor: Good morning, how are you feeling toda...
# 1     Doctor: Hello, how are you feeling today?\nPat...
# 2     Doctor: Hello, how are you feeling today?\nPat...
# 3     Doctor: Hello, how are you feeling today?\nPat...
# 4     Doctor: Good morning, how are you feeling toda...
# ...                                                 ...
# 2995  Doctor: Good afternoon. You were transferred t...
# 2996  Doctor: Hello, how are you feeling today?\nPat...
# 2997  Doctor: Good morning, how are you feeling toda...
# 2998  Doctor: Hello, how are you feeling today?\nPat...
# 2999  Doctor: Hello, how can I help you today?\nPati...
#
# [3000 rows x 2 columns]

# %%
# Randomly sample 1000 rows for analysis
sampled_df = df.sample(n=1000, random_state=42)
sampled_df
# Out:
#                                                    data  \
# 1801  The third case was a 64-year-old female who ad...
# 1190  A 34-year-old woman presented with severe epis...
# 1817  A 53-year-old man, who had non-exertional ches...
# 251   A 34 year old woman from the east of Morocco, ...
# 2505  A 19-year-old male of Caucasian origin was adm...
# ...                                                 ...
# 618   A ten-year-old neutered female Cavalier King C...
# 406   A 65-year-old man with continuous irritable co...
# 1157  A 55-year-old woman without relevant medical h...
# 1068  A 52-year-old man was first diagnosed with HIV...
# 1133  This is a 40-year-old female patient diagnosed...
#
#                                            conversation
# 1801  Doctor: Good afternoon, how are you feeling to...
# 1190  Doctor: Good morning, how can I help you today...
# 1817  Doctor: Hello, Mr. Johnson. How are you feelin...
# 251   Doctor: Good afternoon, Mrs. X. I see here in ...
# 2505  Doctor: Hello, how are you feeling today?\nPat...
# ...                                                 ...
# 618   Doctor: Hello, how are you today?\nPatient: I'...
# 406   Doctor: Good morning, Mr. Johnson. How are you...
# 1157  Doctor: Hi, how are you feeling today?\nPatien...
# 1068  Doctor: Hi there, how are you feeling today?\n...
# 1133  Doctor: Hello, how are you feeling today?\nPat...
#
# [1000 rows x 2 columns]

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Preprocessing function
lemmatizer = WordNetLemmatizer()

# %%
# Define a preprocessing function
def preprocess_text(text):
    # Tokenization
    tokens = word_tokenize(text.lower())
    # Lemmatization
    lemmas = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(lemmas)

# %%
# Apply preprocessing to "data" and "conversation" columns
sampled_df['processed_data'] = sampled_df['data'].apply(preprocess_text)
sampled_df['processed_conversation'] = sampled_df['conversation'].apply(preprocess_text)

# %%
sampled_df
# Out:
#                                                    data  \
# 1801  The third case was a 64-year-old female who ad...
# 1190  A 34-year-old woman presented with severe epis...
# 1817  A 53-year-old man, who had non-exertional ches...
# 251   A 34 year old woman from the east of Morocco, ...
# 2505  A 19-year-old male of Caucasian origin was adm...
# ...                                                 ...
# 618   A ten-year-old neutered female Cavalier King C...
# 406   A 65-year-old man with continuous irritable co...
# 1157  A 55-year-old woman without relevant medical h...
# 1068  A 52-year-old man was first diagnosed with HIV...
# 1133  This is a 40-year-old female patient diagnosed...
#
#                                            conversation  \
# 1801  Doctor: Good afternoon, how are you feeling to...
# 1190  Doctor: Good morning, how can I help you today...
# 1817  Doctor: Hello, Mr. Johnson. How are you feelin...
# 251   Doctor: Good afternoon, Mrs. X. I see here in ...
# 2505  Doctor: Hello, how are you feeling today?\nPat...
# ...                                                 ...
# 618   Doctor: Hello, how are you today?\nPatient: I'...
# 406   Doctor: Good morning, Mr. Johnson. How are you...
# 1157  Doctor: Hi, how are you feeling today?\nPatien...
# 1068  Doctor: Hi there, how are you feeling today?\n...
# 1133  Doctor: Hello, how are you feeling today?\nPat...
#
#                                          processed_data  \
# 1801  the third case wa a 64-year-old female who adm...
# 1190  a 34-year-old woman presented with severe epis...
# 1817  a 53-year-old man , who had non-exertional che...
# 251   a 34 year old woman from the east of morocco ,...
# 2505  a 19-year-old male of caucasian origin wa admi...
# ...                                                 ...
# 618   a ten-year-old neutered female cavalier king c...
# 406   a 65-year-old man with continuous irritable co...
# 1157  a 55-year-old woman without relevant medical h...
# 1068  a 52-year-old man wa first diagnosed with hiv ...
# 1133  this is a 40-year-old female patient diagnosed...
#
#                                  processed_conversation
# 1801  doctor : good afternoon , how are you feeling ...
# 1190  doctor : good morning , how can i help you tod...
# 1817  doctor : hello , mr. johnson . how are you fee...
# 251   doctor : good afternoon , mrs. x. i see here i...
# 2505  doctor : hello , how are you feeling today ? p...
# ...                                                 ...
# 618   doctor : hello , how are you today ? patient :...
# 406   doctor : good morning , mr. johnson . how are ...
# 1157  doctor : hi , how are you feeling today ? pati...
# 1068  doctor : hi there , how are you feeling today ...
# 1133  doctor : hello , how are you feeling today ? p...
#
# [1000 rows x 4 columns]

# %%
# Problem Statement: Generate concise medical summaries from lengthy doctor-patient conversations/patient data for faster review.
# Why: Concise medical summaries streamline documentation, saving time and improving efficiency for healthcare providers. They allow quick review of key information, aiding faster decision-making and better patient care.

# %%
from transformers import pipeline
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the medical text summarization model using a pre-trained model from Hugging Face

summarizer = pipeline("summarization", model="Falconsai/medical_summarization")

# This creates a text summarization pipeline that uses the "Falconsai/medical_summarization" model, which is fine-tuned for summarizing medical texts such as clinical notes, patient records, and research articles.
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Device set to use cpu

# %%
def remove_phrases(text):
    # List of common phrases
    phrases = [
        r'\bhello\b', r'\bhi\b', r'\bhey\b', r'\bhow are you\b',
        r'\bgood morning\b', r'\bgood afternoon\b', r'\bgood evening\b',
        r'\bwhat\'s up\b', r'\bhowdy\b', r'\bgreetings\b',
        r'\bthank you\b', r'\bthanks\b', r'\byou\'re welcome\b',
        r'\bappreciate it\b', r'\bsorry\b', r'\bokay\b', r'\bum\b', r'\byeah\b', r'\bsalutations\b'
    ]

    # Remove greetings and polite phrases
    cleaned_text = re.sub('|'.join(phrases), '', text, flags=re.IGNORECASE)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()  # Remove extra spaces

    return cleaned_text

# %%
# Keyword Extraction using TF-IDF
def extract_keywords(text):
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform([text])
    keywords = [word for word, score in zip(vectorizer.get_feature_names_out(), X.sum(axis=0).tolist()[0]) if score > 0]
    return keywords

# %%
# Function to generate an insightful summary for processed_data
def generate_summary_for_processed_data(text, summarizer):
    summary_data = summarizer(text, max_length=120, min_length=50, do_sample=False)
    return summary_data[0]['summary_text']

# %%
# Function to generate an insightful summary for processed_conversation
def generate_summary_for_processed_conversation(text, summarizer):
    summary_conversation = summarizer(text, max_length=350, min_length=150, do_sample=False)
    return summary_conversation[0]['summary_text']

# %%
# Organize extracted content into sections for processed_data
def create_medical_summary_for_processed_data(text, summarizer):

    keywords = extract_keywords(text)

    summary = generate_summary_for_processed_data(text, summarizer)

    # Structuring the summary
    summary_dict = {

        "Keywords": keywords,
        "Summary": summary

    }
    return summary_dict

# %%
# Organize extracted content into sections for processed_conversation
def create_medical_summary_for_processed_conversation(text, summarizer):

    keywords = extract_keywords(text)

    summary = generate_summary_for_processed_conversation(text, summarizer)

    # Structuring the summary
    summary_dict = {

        "Keywords": keywords,
        "Summary": summary

    }
    return summary_dict

# %%
# Summarization
# Process 5 rows in the processed_conversation
for index, row in sampled_df.head().iterrows():  # Iterating through 5 rows
    conversation_text = row['processed_conversation']  # Extract the processed_data text
    conversation_text = remove_phrases(conversation_text)  # Remove phrases
    summary = create_medical_summary_for_processed_data(conversation_text, summarizer)  # Generate summary for each row

    # Output the structured summary for the current row
    print(f"Summary for row {index}:")
    print(f"Keywords: {summary['Keywords']}")
    print(f"Summary: {summary['Summary']}")
    print("\n" + "-"*50 + "\n")
# Out:
# Summary for row 1801:
# Keywords: ['10', '24', '36', 'able', 'actually', 'administered', 'administration', 'admission', 'admitted', 'alright', 'attack', 'based', 'bleeding', 'blockage', 'blood', 'brain', 'cause', 'cerebellar', 'chest', 'clot', 'complication', 'confirm', 'confirmed', 'consciousness', 'conservatively', 'control', 'coronary', 'day', 'determine', 'diagnosis', 'did', 'discharged', 'dissolve', 'doctor', 'doe', 'electrocardiogram', 'elevation', 'embolism', 'evaluation', 'explaining', 'extubate', 'feeling', 'going', 'great', 'having', 'heart', 'hemorrhage', 'hmm', 'hospital', 'hour', 'hypotension', 'imaging', 'infarction', 'intervention', 'intubate', 'issue', 'later', 'll', 'loss', 'massive', 'medical', 'myocardial', 'need', 'non', 'oh', 'open', 'pain', 'patient', 'pci', 'percutaneous', 'perform', 'persistent', 'possible', 'previous', 'procedure', 'pulmonary', 'rectal', 'remember', 'reteplase', 'run', 'showed', 'st', 'start', 'step', 'symptom', 'test', 'today', 'treated', 'treatment', 'type', 'underwent', 'unfortunately', 'vessel', 'yes']
# Summary: based on your symptom , it 's possible that you may have had a non-st elevation myocardial infarction . we may need to perform a percutaneous coronary intervention to open up any blockage in your blood vessel . however , two day later you had persistent chest pain with hypotension and loss of consciousness , and we had to intubate you . unfortunately , you had some rectal bleeding in the first 24 hour and a cerebellar hemorrhage 36 hour after the rete
#
# --------------------------------------------------
#
# Summary for row 1190:
# Keywords: ['10', '15', '16', 'able', 'admission', 'ago', 'ambulate', 'appears', 'aspect', 'associated', 'away', 'birth', 'blood', 'bony', 'caffeine', 'cc', 'cerebellar', 'change', 'child', 'clear', 'cm', 'column', 'complete', 'complicated', 'complication', 'computed', 'condition', 'continuous', 'contrast', 'coupled', 'csf', 'demonstrate', 'demonstrated', 'descending', 'did', 'difficulty', 'distortion', 'doctor', 'doe', 'dural', 'effect', 'enhanced', 'enhancement', 'epidural', 'exclude', 'excruciating', 'experience', 'experiencing', 'eye', 'family', 'final', 'finding', 'flattened', 'fluid', 'fluoroscopic', 'foramen', 'gave', 'gland', 'globe', 'guided', 'h20', 'h2o', 'ha', 'headache', 'help', 'house', 'hydromorphone', 'hypertension', 'imaging', 'inform', 'infusion', 'injection', 'intracranial', 'intravenous', 'lumbar', 'magnetic', 'magnum', 'matter', 'mean', 'measure', 'measurement', 'method', 'mmhg', 'month', 'morphine', 'nausea', 'need', 'nerve', 'noncontrast', 'notice', 'noticed', 'opening', 'optic', 'pain', 'passed', 'past', 'patient', 'perform', 'photophobia', 'pituitary', 'position', 'possible', 'posterior', 'posture', 'pressure', 'procedure', 'progressively', 'puncture', 'rated', 'received', 'relationship', 'relief', 'removed', 'reported', 'resolution', 'resonance', 'result', 'scan', 'scotoma', 'sella', 'severe', 'severity', 'shrink', 'significant', 'sound', 'start', 'structure', 'symptom', 'syndrome', 'tablet', 'test', 'today', 'tomographic', 'tonsil', 'topiramate', 'total', 'turcica', 'underwent', 'visual', 'wa', 'worsened', 'yes']
# Summary: magnetic resonance imaging ha demonstrated finding of empty sella syndrome with no distortion of optic nerve or posterior aspect of the optic globe . we will need to do a fluoroscopic-guided lumbar puncture to measure your csf pressure to exclude intracranial hypertension . patient : a continuous and excruciating headache that progressively worsened and wa rated a 10/10 in severity . a contrast-enhanced computed tomographic scan did not demonstrate any dural enhancement .
#
# --------------------------------------------------
#
# Summary for row 1817:
# Keywords: ['141', '43', '60', '625', 'angioplasty', 'aortic', 'approach', 'artery', 'atrial', 'atriotomy', 'atrium', 'autologous', 'bare', 'benign', 'bit', 'blockage', 'bypass', 'cardiology', 'central', 'chest', 'clinic', 'closing', 'condition', 'consisted', 'coronary', 'correct', 'decided', 'defective', 'deformation', 'degree', 'department', 'detected', 'diagnosis', 'did', 'dilatation', 'dizzy', 'doctor', 'doe', 'drug', 'echocardiography', 'effusion', 'ejection', 'eluting', 'ensure', 'estimated', 'excised', 'excision', 'exclude', 'exercise', 'exertional', 'experience', 'feeling', 'fibrosis', 'fixed', 'follow', 'following', 'fraction', 'frozen', 'giant', 'glutaraldehyde', 'graft', 'healing', 'heart', 'hospitalization', 'hospitalized', 'hypertrophic', 'hypotensive', 'inserted', 'intact', 'intraoperative', 'invaded', 'jet', 'johnson', 'just', 'la', 'lead', 'left', 'mass', 'mean', 'median', 'metal', 'minute', 'mitral', 'mmhg', 'monitor', 'mr', 'myocardium', 'myxoma', 'nature', 'nearby', 'necrotic', 'need', 'non', 'occlusion', 'order', 'pacemaker', 'pain', 'pathology', 'patient', 'pd', 'percutaneous', 'perform', 'performed', 'pericardial', 'pericardium', 'positive', 'possible', 'posterior', 'pressure', 'procedure', 'proper', 'pulmonary', 'question', 'rca', 'reached', 'regularly', 'regurgitant', 'repaired', 'reported', 'resected', 'resemble', 'rich', 'right', 'saphenous', 'saw', 'segment', 'sent', 'septum', 'solution', 'specimen', 'stent', 'sternotomy', 'stress', 'surgery', 'surgical', 'symptom', 'systolic', 'temporary', 'test', 'time', 'tissue', 'today', 'total', 'transluminal', 'transseptal', 'transthoracic', 'tricuspid', 'understand', 'underwent', 'using', 'valve', 'vein', 'ventricular', 'wa', 'wall', 'yes']
# Summary: a transthoracic echocardiography wa performed , and a mass wa detected in the left atrium with la dilatation and estimated systolic pulmonary artery pressure over tricuspid regurgitant jet wa 43 mmhg . after the procedure , you became hypotensive . did you experience any other symptom ? patient : no , just feeling a bit dizzy . we decided to perform surgical excision of the mass . following median sternotomy , we reached
#
# --------------------------------------------------
#
# Summary for row 251:
# Keywords: ['abdominal', 'acute', 'admitted', 'adverse', 'allowing', 'amniotic', 'anesthesia', 'assistance', 'associated', 'birth', 'carefully', 'ceolioscopic', 'cesarean', 'clinical', 'cm', 'correct', 'day', 'decided', 'developing', 'development', 'diagnosis', 'did', 'discharged', 'discussed', 'discussing', 'dissecting', 'doctor', 'doe', 'emergency', 'end', 'estimated', 'event', 'evolution', 'evolving', 'examination', 'exceptional', 'exploration', 'external', 'fetal', 'fetus', 'fluid', 'follow', 'gave', 'general', 'good', 'gravid', 'harm', 'head', 'hear', 'hernia', 'impulsive', 'infant', 'injection', 'intense', 'intestinal', 'intraperitoneal', 'irreducible', 'kg', 'later', 'level', 'ligation', 'loop', 'male', 'manual', 'mass', 'mean', 'medical', 'mono', 'mri', 'mrs', 'multidisciplinary', 'nature', 'normal', 'obstetrical', 'oh', 'opted', 'orifice', 'ovary', 'pain', 'painful', 'patient', 'pelvic', 'perform', 'performed', 'periumbilical', 'placing', 'plate', 'postoperative', 'potentially', 'pregnancy', 'pregnant', 'prior', 'procedure', 'providing', 'psychomotor', 'record', 'recurrence', 'reduced', 'resulting', 'right', 'room', 'sac', 'scan', 'scheduled', 'section', 'showed', 'strangulated', 'strangulation', 'surgery', 'team', 'teratogenic', 'tolerated', 'tubal', 'ultrasound', 'umbilical', 'unfortunately', 'uterus', 'visceral', 'vomiting', 'wa', 'weight', 'went', 'year', 'yes']
# Summary: mrs. x. i see here in your medical record that you were admitted to the emergency room with intense periumbilical and pelvic abdominal pain associated with acute vomiting . is that correct ? patient : yes , doctor . that 's right . doctor : during the clinical examination , we found an irreducible and impulsive painful mass at the umbilical level . we performed an abdominal ultrasound scan , which showed an evolving mono-fetal pregnancy with an estimated weight of 1 kg and a normal
#
# --------------------------------------------------
#
# Summary for row 2505:
# Keywords: ['113', '143', '159', '21', '2335', '36', '52', '55', '57', '781', '93', 'accident', 'according', 'achieve', 'admission', 'admitted', 'adult', 'alanine', 'alkaline', 'alp', 'alright', 'alt', 'ards', 'basically', 'bilateral', 'bilirubin', 'bit', 'blood', 'breathing', 'care', 'cell', 'change', 'circuit', 'clinical', 'contusion', 'day', 'decannulated', 'decannulation', 'department', 'developed', 'did', 'difficulty', 'discharged', 'distress', 'doctor', 'doing', 'ecmo', 'emergency', 'ensure', 'eventually', 'experienced', 'experiencing', 'extent', 'extracorporeal', 'feeling', 'femoral', 'follow', 'forward', 'fracture', 'fresh', 'frozen', 'function', 'functioning', 'general', 'given', 'glad', 'going', 'haemothorax', 'happen', 'happened', 'having', 'hear', 'hemorrhage', 'hospital', 'imagine', 'including', 'increase', 'increased', 'injury', 'intensive', 'intubated', 'iu', 'laparotomy', 'lesser', 'like', 'liver', 'local', 'lot', 'major', 'make', 'mean', 'membrane', 'monitor', 'month', 'motorcycle', 'multiple', 'need', 'note', 'number', 'oxygenation', 'packed', 'pain', 'patient', 'peaking', 'pelvic', 'period', 'persistent', 'phosphatase', 'plasma', 'pneumothoraces', 'possibly', 'pressure', 'pretty', 'proceeding', 'prolonged', 'properly', 'protocol', 'pulmonary', 'question', 'really', 'recall', 'receiving', 'recovering', 'recovery', 'red', 'rehabilitation', 'remember', 'required', 'respiratory', 'resuscitated', 'rise', 'road', 'rose', 'sense', 'sequential', 'showed', 'slowly', 'splenectomy', 'stepped', 'struggle', 'subsequently', 'sure', 'sustained', 'symptom', 'syndrome', 'tell', 'test', 'thoracotomy', 'time', 'today', 'traffic', 'transaminase', 'transferred', 'trauma', 'understandable', 'underwent', 'unit', 'unstable', 'using', 'veno', 'venous', 'wa', 'ward', 'weak', 'yes', 'μmol']
# Summary: alanine transaminase ( alt ) increased from 55 to 143 iu/l between day 1 and day 6 of hospital admission . the bilirubin did not rise above 57 mol/l . this can happen after a major trauma like the one you experienced . we will need to monitor your liver function going forward and possibly do some follow up test to ensure everything is functioning properly .
#
# --------------------------------------------------

# %%
# Summarization
# Process 5 rows in the processed_data
for index, row in sampled_df.head().iterrows():  # Iterating through 5 rows
    data_text = row['processed_data']  # Extract the processed_data text
    data_text = remove_phrases(data_text)  # Remove phrases
    summary = create_medical_summary_for_processed_data(data_text, summarizer)  # Generate summary for each row

    # Output the structured summary for the current row
    print(f"Summary for row {index}:")
    print(f"Keywords: {summary['Keywords']}")
    print(f"Summary: {summary['Summary']}")
    print("\n" + "-"*50 + "\n")
# Out:
# Summary for row 1801:
# Keywords: ['10', '24', '36', '64', 'administered', 'administration', 'admission', 'admitted', 'brain', 'case', 'cerebellar', 'chest', 'complication', 'confirmed', 'consciousness', 'conservatively', 'control', 'coronary', 'day', 'discharged', 'elevation', 'extubate', 'female', 'following', 'hemorrhage', 'hour', 'hypotension', 'imaging', 'infarction', 'intervention', 'intubated', 'loss', 'massive', 'myocardial', 'non', 'old', 'pain', 'patient', 'pci', 'percutaneous', 'persistent', 'pte', 'rectorrhagia', 'reteplase', 'showed', 'st', 'treated', 'underwent', 'wa', 'year']
# Summary: the third case wa a 64-year-old female who admitted with chest pain and non-st elevation myocardial infarction ; during admission she underwent percutaneous coronary intervention . two day following pci , the patient had persistent chest pain with hypotension and loss of consciousness , and wa intubated . imaging confirmed massive pte and reteplase wa administered .
#
# --------------------------------------------------
#
# Summary for row 1190:
# Keywords: ['10', '15', '16', '34', 'able', 'admission', 'ago', 'ambulate', 'aspect', 'associated', 'birth', 'blood', 'caffeine', 'cc', 'cerebellar', 'child', 'clear', 'cm', 'column', 'complete', 'computed', 'continuous', 'contrast', 'coupled', 'csf', 'demonstrate', 'demonstrated', 'descending', 'described', 'did', 'difficulty', 'distortion', 'dural', 'enhanced', 'enhancement', 'epidural', 'episodic', 'exclude', 'excruciating', 'eye', 'final', 'finding', 'fluid', 'fluoroscopic', 'foramen', 'giving', 'globe', 'guided', 'h20', 'h2o', 'headache', 'hydromorphone', 'hypertension', 'imaging', 'infusion', 'injection', 'intracranial', 'intravenous', 'lumbar', 'magnetic', 'magnum', 'measure', 'measurement', 'method', 'mmhg', 'month', 'morphine', 'nausea', 'nerve', 'noncontrast', 'old', 'opening', 'optic', 'pain', 'patient', 'performed', 'photophobia', 'posterior', 'postprocedure', 'posture', 'presented', 'pressure', 'procedure', 'progressively', 'puncture', 'rated', 'received', 'relationship', 'relief', 'removed', 'reported', 'resolution', 'resonance', 'scan', 'scotoma', 'sella', 'severe', 'severity', 'significant', 'started', 'syndrome', 'tablet', 'tomographic', 'tonsil', 'topiramate', 'total', 'underwent', 'visual', 'vomiting', 'wa', 'woman', 'worsened', 'worsening', 'year']
# Summary: a 34-year-old woman presented with severe episodic headache that started after giving birth to a child 5 month ago which wa rated 5/10 in severity . the headache were associated with nausea , vomiting , and photophobia with no clear relationship to posture . a patient also reported visual scotoma in both the eye . magnetic resonance imaging demonstrated finding of empty sella syndrome but there wa no distortion of optic nerve or posterior aspect of the optic globe .
#
# --------------------------------------------------
#
# Summary for row 1817:
# Keywords: ['141', '43', '53', '5x4', '60', '625', 'angioplasty', 'aortic', 'approach', 'artery', 'atrial', 'atriotomy', 'atrium', 'autologous', 'bare', 'benign', 'blockage', 'bm', 'bypass', 'cardiology', 'cath', 'central', 'chest', 'clinic', 'closing', 'cm', 'consisted', 'coronary', 'decided', 'defective', 'deformation', 'degree', 'department', 'detected', 'diagnosis', 'did', 'dilatation', 'drug', 'echocardiography', 'effusion', 'ejection', 'eluting', 'estimated', 'excised', 'excision', 'exclude', 'exercise', 'exertional', 'fibrosis', 'fixed', 'following', 'fraction', 'frozen', 'giant', 'glutaraldehyde', 'graft', 'heart', 'hospitalized', 'hypertrophic', 'hypotensive', 'inserted', 'intact', 'intraoperative', 'invaded', 'jet', 'la', 'lab', 'lead', 'left', 'long', 'lvef', 'man', 'mass', 'median', 'metal', 'minute', 'mitral', 'mmhg', 'myocardium', 'myxoma', 'nature', 'nearby', 'necrotic', 'non', 'occlusion', 'old', 'order', 'pacemaker', 'pain', 'pathology', 'patient', 'pd', 'percutaneous', 'perform', 'performed', 'performing', 'pericardial', 'pericardium', 'placed', 'positive', 'possible', 'posterior', 'pressure', 'procedure', 'ptca', 'pulmonary', 'rca', 'reached', 'regurgitant', 'repaired', 'reported', 'resected', 'resemble', 'rich', 'right', 'saphenous', 'saw', 'segment', 'sent', 'septum', 'shown', 'solution', 'specimen', 'stent', 'sternotomy', 'stress', 'surgery', 'surgical', 'systolic', 'temporary', 'test', 'time', 'tissue', 'total', 'transluminal', 'transseptal', 'transthoracic', 'tricuspid', 'using', 'valve', 'vein', 'ventricular', 'view', 'wa', 'wall', 'year']
# Summary: a 53-year - old man , who had non-exertional chest pain with positive exercise stress test , wa hospitalized by the cardiology department . total occlusion of the right coronary artery ( rca ) wa detected in the cath-lab . after performing percutaneous transluminal angioplasty , long segment drug-eluting stent ( de ) and bare-metal ( bm ) were placed.after the procedure he became hypotensive
#
# --------------------------------------------------
#
# Summary for row 251:
# Keywords: ['34', 'abdominal', 'acute', 'admitted', 'adverse', 'allowing', 'amniotic', 'anesthesia', 'assistance', 'associated', 'birth', 'carefully', 'case', 'ceolioscopic', 'cesarean', 'child', 'clinical', 'cm', 'conscious', 'day', 'decision', 'development', 'diagnosis', 'did', 'discharged', 'discussed', 'discussion', 'dissection', 'east', 'emergency', 'end', 'estimated', 'event', 'evolution', 'evolving', 'examination', 'exceptional', 'exploration', 'external', 'faced', 'fetal', 'fluid', 'follow', 'general', 'giving', 'good', 'gravid', 'head', 'hernia', 'impulsive', 'infant', 'inguinal', 'injection', 'intense', 'intestinal', 'intraperitoneal', 'irreducible', 'kg', 'later', 'level', 'ligation', 'loop', 'male', 'manual', 'married', 'mass', 'metrorrhagia', 'mono', 'morocco', 'mother', 'mri', 'multidisciplinary', 'nature', 'normal', 'notion', 'obstetrical', 'old', 'opted', 'opting', 'orifice', 'ovary', 'pain', 'painful', 'patient', 'pelvic', 'perform', 'performed', 'periumbilical', 'placement', 'plate', 'postoperative', 'pregnancy', 'pregnant', 'presentation', 'prior', 'procedure', 'psychomotor', 'quickly', 'radiological', 'recurrence', 'reduced', 'reminiscent', 'resulted', 'revealed', 'right', 'room', 'sac', 'scan', 'scheduled', 'section', 'showed', 'shown', 'strangulated', 'strangulation', 'surgery', 'team', 'teratogenic', 'tolerated', 'tubal', 'ultrasound', 'umbilical', 'uterus', 'visceral', 'vomiting', 'wa', 'weight', 'went', 'woman', 'year']
# Summary: a 34 year old woman from the east of morocco admitted to the emergency room with intense periumbilical and pelvic abdominal pain associated with acute vomiting without any notion of metrorrhagia . the clinical examination revealed a conscious patient with an irreducible and impulsive painful mass at the umbilical level reminiscent of a strangulated inguinal hernia ( ) . we performed an abdominal ultrasound scan which showed an evolving mono-fetal pregnancy ; with an estimated weight of 1 kg , and
#
# --------------------------------------------------
#
# Summary for row 2505:
# Keywords: ['10', '113', '143', '15', '159', '19', '21', '2335', '36', '52', '55', '57', '781', '93', 'accident', 'achieve', 'admission', 'admitted', 'adult', 'alanine', 'alcohol', 'alkaline', 'alp', 'alt', 'approximately', 'ards', 'bilateral', 'bilirubin', 'blood', 'care', 'caucasian', 'caused', 'cell', 'center', 'change', 'circuit', 'collided', 'commencement', 'contusion', 'culminated', 'day', 'decannulated', 'decannulation', 'department', 'did', 'discharged', 'distress', 'ecmo', 'emergency', 'extensive', 'extent', 'extracorporeal', 'extremis', 'feature', 'femoral', 'fit', 'fracture', 'fresh', 'frozen', 'function', 'general', 'haemothorax', 'hemorrhage', 'hospital', 'hypovolemic', 'hypoxic', 'including', 'increase', 'increased', 'increasingly', 'injury', 'intake', 'intensive', 'intubated', 'iu', 'laparotomy', 'lesser', 'liver', 'local', 'major', 'male', 'massive', 'membrane', 'modest', 'month', 'motorcycle', 'multiple', 'nonsmoker', 'old', 'oncoming', 'origin', 'oxygenation', 'packed', 'pattern', 'peaking', 'pelvic', 'period', 'persistent', 'phosphatase', 'plasma', 'pneumothoraces', 'polytrauma', 'presentation', 'presented', 'pressure', 'previously', 'proceeding', 'prolonged', 'protocol', 'pulmonary', 'receiving', 'recovery', 'red', 'rehabilitation', 'relatively', 'required', 'respiratory', 'resuscitated', 'returned', 'rise', 'road', 'rose', 'sequential', 'shock', 'sign', 'significant', 'splenectomy', 'splenic', 'stepped', 'subsequently', 'sustain', 'syndrome', 'test', 'theater', 'thoracotomy', 'traffic', 'transaminase', 'transferred', 'underwent', 'unit', 'unstable', 'using', 'vehicle', 'veno', 'venous', 'wa', 'ward', 'year', 'μmol']
# Summary: a 19-year-old male of caucasian origin wa admitted to our center a polytrauma after a road traffic accident . he wa previously fit and well , a nonsmoker with an alcohol intake of approximately 10 unit per month . the accident , in which his motorcycle collided with an oncoming vehicle , caused him to sustain multiple significant injury including unstable pelvic fracture and femoral fracture .
#
# --------------------------------------------------
